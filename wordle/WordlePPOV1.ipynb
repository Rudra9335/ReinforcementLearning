# %%
#https://keras.io/examples/rl/ppo_cartpole/
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.layers import Multiply
import scipy.signal
import time
import pandas as pd
import random
import string
import random

# %% [markdown]
# ### Environment Functions

# %%
# https://gist.github.com/cfreshman/a03ef2cba789d8cf00c08f767e0fad7b
my_file = open("C:/Users/rudra/OneDrive/Desktop/reinforcementLearning/Wordle/data/wordle-answers-alphabetical.txt", "r")
content = my_file.read()
content = list(content.split('\n'))
# limiting to only a 100 words to ensure that the model is converging
content = random.sample(content, 100)

# %%
lower_alphabet = list(string.ascii_letters)[:26]

# %%
# Initialize the environment and get the dimensionality of the
# observation space and the number of possible actions
observation_dimensions = 182
num_actions = len(content)

# %%
def get_secret_word():
    return random.choice(content)

# %%
def reset_available_action_space():
    return [1.0 for i in range(len(content))]

def reset_guessed_alphabet_state():
    return [0 for i in range(len(lower_alphabet))]

# array of 26 which represents which alphabet is available in word
def reset_contains_alphabet_state():
    return [0 for i in range(len(lower_alphabet))]

# Array of 26*5. 
# First 26 represent which alphabet was correctly guessed at the first slot
# Second 26 represent which alphabet was correctly guessed at the second slot. And so on for the next 5 slots.
def reset_correct_alphabet_pos_state():
    return [0 for i in range(len(lower_alphabet)*5)]

# %%
def update_AVAILABLE_ACTION_SPACE(action):
    AVAILABLE_ACTION_SPACE[action] = 0

# %%
def env_reset():
    AVAILABLE_ACTION_SPACE = reset_available_action_space()
    guessed_alphabet_state = reset_guessed_alphabet_state()
    contains_alphabet_state = reset_contains_alphabet_state()
    correct_alphabet_pos_state = reset_correct_alphabet_pos_state()
    state = np.array(guessed_alphabet_state + contains_alphabet_state + correct_alphabet_pos_state)
    SECRET_WORD = get_secret_word()
    return state, SECRET_WORD, AVAILABLE_ACTION_SPACE

# %%
def env_step(action, observation):
    state = observation[0].tolist()
    guessed_word = content[action]
    guessed_alphabet_state = state[:26]
    contains_alphabet_state = state[26:52]
    correct_alphabet_pos_state = state[52:]
    
    done = False
    reward = 0
    
    if SECRET_WORD == guessed_word:
        done = True
        reward = 10
    secret_word = list(SECRET_WORD)
    guessed_word = list(guessed_word)
    for index_, char_ in enumerate(guessed_word):
        alphabet_index = lower_alphabet.index(char_)
        guessed_alphabet_state[alphabet_index] = 1
        if char_ in secret_word:
            contains_alphabet_state[alphabet_index] = 1
            if secret_word[index_] == char_:
                correct_alphabet_pos_state[26*index_ + alphabet_index] = 1
    state = np.array(guessed_alphabet_state + contains_alphabet_state + correct_alphabet_pos_state)
    return state, reward, done

# %% [markdown]
# ### PPO

# %%
def discounted_cumulative_sums(x, discount):
    # Discounted cumulative sums of vectors for computing rewards-to-go and advantage estimates
    return scipy.signal.lfilter([1], [1, float(-discount)], x[::-1], axis=0)[::-1]


class Buffer:
    # Buffer for storing trajectories
    def __init__(self, observation_dimensions, size, gamma=0.99, lam=0.95):
        # Buffer initialization
        self.observation_buffer = np.zeros(
            (size, observation_dimensions), dtype=np.float32
        )
        self.action_buffer = np.zeros(size, dtype=np.int32)
        self.advantage_buffer = np.zeros(size, dtype=np.float32)
        self.reward_buffer = np.zeros(size, dtype=np.float32)
        self.return_buffer = np.zeros(size, dtype=np.float32)
        self.value_buffer = np.zeros(size, dtype=np.float32)
        self.logprobability_buffer = np.zeros(size, dtype=np.float32)
        self.gamma, self.lam = gamma, lam
        self.pointer, self.trajectory_start_index = 0, 0

    def store(self, observation, action, reward, value, logprobability):
        # Append one step of agent-environment interaction
        self.observation_buffer[self.pointer] = observation
        self.action_buffer[self.pointer] = action
        self.reward_buffer[self.pointer] = reward
        self.value_buffer[self.pointer] = value
        self.logprobability_buffer[self.pointer] = logprobability
        self.pointer += 1

    def finish_trajectory(self, last_value=0):
        # Finish the trajectory by computing advantage estimates and rewards-to-go
        path_slice = slice(self.trajectory_start_index, self.pointer)
        rewards = np.append(self.reward_buffer[path_slice], last_value)
        values = np.append(self.value_buffer[path_slice], last_value)

        deltas = rewards[:-1] + self.gamma * values[1:] - values[:-1]

        self.advantage_buffer[path_slice] = discounted_cumulative_sums(
            deltas, self.gamma * self.lam
        )
        self.return_buffer[path_slice] = discounted_cumulative_sums(
            rewards, self.gamma
        )[:-1]

        self.trajectory_start_index = self.pointer

    def get(self):
        # Get all data of the buffer and normalize the advantages
        self.pointer, self.trajectory_start_index = 0, 0
        advantage_mean, advantage_std = (
            np.mean(self.advantage_buffer),
            np.std(self.advantage_buffer),
        )
        self.advantage_buffer = (self.advantage_buffer - advantage_mean) / advantage_std
        return (
            self.observation_buffer,
            self.action_buffer,
            self.advantage_buffer,
            self.return_buffer,
            self.logprobability_buffer,
        )


def mlp(x, sizes, activation=tf.tanh, output_activation=None):
    # Build a feedforward neural network
    for size in sizes[:-1]:
        x = layers.Dense(units=size, activation=activation)(x)
    return layers.Dense(units=sizes[-1], activation=output_activation)(x)


def logprobabilities(logits, a):
    # Compute the log-probabilities of taking actions a by using the logits (i.e. the output of the actor)
    logprobabilities_all = tf.nn.log_softmax(logits)
    logprobability = tf.reduce_sum(
        tf.one_hot(a, num_actions) * logprobabilities_all, axis=1
    )
    return logprobability


# Sample action from actor
# @tf.function
def sample_action(observation):
    logits = actor(observation)
    available_action_tensor = tf.expand_dims(tf.convert_to_tensor(AVAILABLE_ACTION_SPACE), 0)
    logits = tf.add(logits, 1.0)
    logits = Multiply()([logits, available_action_tensor])
    logits = tf.add(logits, -1.0)
    action = tf.squeeze(tf.random.categorical(logits, 1), axis=1)
    return logits, action


# Train the policy by maxizing the PPO-Clip objective
@tf.function
def train_policy(
    observation_buffer, action_buffer, logprobability_buffer, advantage_buffer
):

    with tf.GradientTape() as tape:  # Record operations for automatic differentiation.
        ratio = tf.exp(
            logprobabilities(actor(observation_buffer), action_buffer)
            - logprobability_buffer
        )
        min_advantage = tf.where(
            advantage_buffer > 0,
            (1 + clip_ratio) * advantage_buffer,
            (1 - clip_ratio) * advantage_buffer,
        )

        policy_loss = -tf.reduce_mean(
            tf.minimum(ratio * advantage_buffer, min_advantage)
        )
    policy_grads = tape.gradient(policy_loss, actor.trainable_variables)
    policy_optimizer.apply_gradients(zip(policy_grads, actor.trainable_variables))

    kl = tf.reduce_mean(
        logprobability_buffer
        - logprobabilities(actor(observation_buffer), action_buffer)
    )
    kl = tf.reduce_sum(kl)
    return kl


# Train the value function by regression on mean-squared error
@tf.function
def train_value_function(observation_buffer, return_buffer):
    with tf.GradientTape() as tape:  # Record operations for automatic differentiation.
        value_loss = tf.reduce_mean((return_buffer - critic(observation_buffer)) ** 2)
    value_grads = tape.gradient(value_loss, critic.trainable_variables)
    value_optimizer.apply_gradients(zip(value_grads, critic.trainable_variables))

# %%
# Hyperparameters of the PPO algorithm
games_per_epoch = 100
game_length = 6
epochs = 10000
gamma = 0.99
clip_ratio = 0.2
policy_learning_rate = 3e-4
value_function_learning_rate = 1e-3
train_policy_iterations = 80
train_value_iterations = 80
lam = 0.97
target_kl = 0.01
hidden_sizes = (256, 256, 128)

# %%
# Initialize the buffer
buffer = Buffer(observation_dimensions, games_per_epoch*game_length)

# Initialize the actor and the critic as keras models
observation_input = keras.Input(shape=(observation_dimensions,), dtype=tf.float32)
logits = mlp(observation_input, list(hidden_sizes) + [num_actions], tf.tanh, None)
actor = keras.Model(inputs=observation_input, outputs=logits)
value = tf.squeeze(
    mlp(observation_input, list(hidden_sizes) + [1], tf.tanh, None), axis=1
)
critic = keras.Model(inputs=observation_input, outputs=value)

# Initialize the policy and the value function optimizers
policy_optimizer = keras.optimizers.Adam(learning_rate=policy_learning_rate)
value_optimizer = keras.optimizers.Adam(learning_rate=value_function_learning_rate)

# Initialize the observation, episode return and episode length
observation, SECRET_WORD, AVAILABLE_ACTION_SPACE = env_reset()
episode_return, episode_length = 0, 0

# %%
# Iterate over the number of epochs
for epoch in range(epochs):
    # Initialize the sum of the returns, lengths and number of episodes for each epoch
    sum_return = 0
    sum_length = 0
    num_episodes = 0
    # Iterate over the steps of each epoch
    for game_in_epoch in range(games_per_epoch):
        for game in range(game_length):
        # Get the logits, action, and take one step in the environment
            observation = observation.reshape(1, -1)
            logits, action = sample_action(observation)
            action_index = int(action[0].numpy())
            update_AVAILABLE_ACTION_SPACE(action_index)
            observation_new, reward, done = env_step(action_index, observation)
            reward = reward * (game_length - game)
            episode_return += reward
            episode_length += 1

            # Get the value and log-probability of the action
            value_t = critic(observation)
            logprobability_t = logprobabilities(logits, action)

            # Store obs, act, rew, v_t, logp_pi_t
            buffer.store(observation, action, reward, value_t, logprobability_t)

            # Update the observation
            observation = observation_new

            # Finish trajectory if reached to a terminal state
            terminal = done
            if terminal or game == game_length-1:
                last_value = 0 if done else critic(observation.reshape(1, -1))
                buffer.finish_trajectory(last_value)
                sum_return += episode_return
                sum_length += episode_length
                num_episodes += 1
                observation, SECRET_WORD, AVAILABLE_ACTION_SPACE = env_reset()
                episode_return, episode_length = 0, 0
                break
    # Get values from the buffer
    (
        observation_buffer,
        action_buffer,
        advantage_buffer,
        return_buffer,
        logprobability_buffer,
    ) = buffer.get()

    # Update the policy and implement early stopping using KL divergence
    for _ in range(train_policy_iterations):
        kl = train_policy(
            observation_buffer, action_buffer, logprobability_buffer, advantage_buffer
        )
        if kl > 1.5 * target_kl:
            # Early Stopping
            break

    # Update the value function
    for _ in range(train_value_iterations):
        train_value_function(observation_buffer, return_buffer)

    # Print mean return and length for each epoch
    if epoch % 10 == 0:
        print(
            f" Epoch: {epoch + 1}. Mean Return: {sum_return / num_episodes}. Mean Length: {sum_length / num_episodes}"
        )       
# Model converged to about 2.8 average attempts for every 100 games
# Out:
#  Epoch: 1. Mean Return: 2.1. Mean Length: 5.85
#  Epoch: 11. Mean Return: 2.2. Mean Length: 5.84
#  Epoch: 21. Mean Return: 1.6. Mean Length: 5.88
#  Epoch: 31. Mean Return: 3.1. Mean Length: 5.77
#  Epoch: 41. Mean Return: 2.4. Mean Length: 5.82
#  Epoch: 51. Mean Return: 0.9. Mean Length: 5.94
#  Epoch: 61. Mean Return: 2.4. Mean Length: 5.82
#  Epoch: 71. Mean Return: 2.6. Mean Length: 5.81
#  Epoch: 81. Mean Return: 1.2. Mean Length: 5.93
#  Epoch: 91. Mean Return: 2.8. Mean Length: 5.8
#  Epoch: 101. Mean Return: 1.2. Mean Length: 5.94
#  Epoch: 111. Mean Return: 2.6. Mean Length: 5.83
#  Epoch: 121. Mean Return: 2.2. Mean Length: 5.87
#  Epoch: 131. Mean Return: 2.2. Mean Length: 5.84
#  Epoch: 141. Mean Return: 1.1. Mean Length: 5.94
#  Epoch: 151. Mean Return: 1.2. Mean Length: 5.91
#  Epoch: 161. Mean Return: 1.5. Mean Length: 5.9
#  Epoch: 171. Mean Return: 1.9. Mean Length: 5.88
#  Epoch: 181. Mean Return: 3.7. Mean Length: 5.72
#  Epoch: 191. Mean Return: 3.2. Mean Length: 5.76
#  Epoch: 201. Mean Return: 2.2. Mean Length: 5.89
#  Epoch: 211. Mean Return: 2.7. Mean Length: 5.82
#  Epoch: 221. Mean Return: 1.9. Mean Length: 5.86
#  Epoch: 231. Mean Return: 2.7. Mean Length: 5.84
#  Epoch: 241. Mean Return: 3.6. Mean Length: 5.77
#  Epoch: 251. Mean Return: 3.0. Mean Length: 5.8
#  Epoch: 261. Mean Return: 4.3. Mean Length: 5.7
#  Epoch: 271. Mean Return: 2.9. Mean Length: 5.81
#  Epoch: 281. Mean Return: 2.5. Mean Length: 5.81
#  Epoch: 291. Mean Return: 2.0. Mean Length: 5.88
#  Epoch: 301. Mean Return: 2.8. Mean Length: 5.81
#  Epoch: 311. Mean Return: 4.7. Mean Length: 5.68
#  Epoch: 321. Mean Return: 2.7. Mean Length: 5.83
#  Epoch: 331. Mean Return: 2.9. Mean Length: 5.79
#  Epoch: 341. Mean Return: 3.7. Mean Length: 5.76
#  Epoch: 351. Mean Return: 4.2. Mean Length: 5.75
#  Epoch: 361. Mean Return: 3.2. Mean Length: 5.78
#  Epoch: 371. Mean Return: 3.5. Mean Length: 5.75
#  Epoch: 381. Mean Return: 4.0. Mean Length: 5.72
#  Epoch: 391. Mean Return: 3.5. Mean Length: 5.75
#  Epoch: 401. Mean Return: 3.1. Mean Length: 5.82
#  Epoch: 411. Mean Return: 5.0. Mean Length: 5.66
#  Epoch: 421. Mean Return: 5.9. Mean Length: 5.58
#  Epoch: 431. Mean Return: 6.4. Mean Length: 5.55
#  Epoch: 441. Mean Return: 4.9. Mean Length: 5.68
#  Epoch: 451. Mean Return: 6.8. Mean Length: 5.51
#  Epoch: 461. Mean Return: 5.2. Mean Length: 5.64
#  Epoch: 471. Mean Return: 4.6. Mean Length: 5.69
#  Epoch: 481. Mean Return: 5.4. Mean Length: 5.62
#  Epoch: 491. Mean Return: 6.1. Mean Length: 5.57
#  Epoch: 501. Mean Return: 4.2. Mean Length: 5.74
#  Epoch: 511. Mean Return: 3.4. Mean Length: 5.79
#  Epoch: 521. Mean Return: 7.1. Mean Length: 5.51
#  Epoch: 531. Mean Return: 6.1. Mean Length: 5.61
#  Epoch: 541. Mean Return: 5.3. Mean Length: 5.64
#  Epoch: 551. Mean Return: 3.7. Mean Length: 5.75
#  Epoch: 561. Mean Return: 6.4. Mean Length: 5.54
#  Epoch: 571. Mean Return: 6.0. Mean Length: 5.58
#  Epoch: 581. Mean Return: 7.0. Mean Length: 5.53
#  Epoch: 591. Mean Return: 6.3. Mean Length: 5.57
#  Epoch: 601. Mean Return: 6.9. Mean Length: 5.55
#  Epoch: 611. Mean Return: 4.5. Mean Length: 5.7
#  Epoch: 621. Mean Return: 8.5. Mean Length: 5.36
#  Epoch: 631. Mean Return: 8.5. Mean Length: 5.39
#  Epoch: 641. Mean Return: 2.5. Mean Length: 5.85
#  Epoch: 651. Mean Return: 6.6. Mean Length: 5.58
#  Epoch: 661. Mean Return: 5.8. Mean Length: 5.61
#  Epoch: 671. Mean Return: 5.1. Mean Length: 5.66
#  Epoch: 681. Mean Return: 7.1. Mean Length: 5.53
#  Epoch: 691. Mean Return: 4.7. Mean Length: 5.68
#  Epoch: 701. Mean Return: 9.5. Mean Length: 5.35
#  Epoch: 711. Mean Return: 4.5. Mean Length: 5.72
#  Epoch: 721. Mean Return: 4.1. Mean Length: 5.72
#  Epoch: 731. Mean Return: 7.9. Mean Length: 5.46
#  Epoch: 741. Mean Return: 5.3. Mean Length: 5.64
#  Epoch: 751. Mean Return: 7.4. Mean Length: 5.52
#  Epoch: 761. Mean Return: 10.8. Mean Length: 5.28
#  Epoch: 771. Mean Return: 8.1. Mean Length: 5.41
#  Epoch: 781. Mean Return: 8.0. Mean Length: 5.42
#  Epoch: 791. Mean Return: 5.3. Mean Length: 5.65
#  Epoch: 801. Mean Return: 8.0. Mean Length: 5.44
#  Epoch: 811. Mean Return: 8.2. Mean Length: 5.44
#  Epoch: 821. Mean Return: 5.7. Mean Length: 5.62
#  Epoch: 831. Mean Return: 6.5. Mean Length: 5.57
#  Epoch: 841. Mean Return: 6.2. Mean Length: 5.57
#  Epoch: 851. Mean Return: 10.0. Mean Length: 5.26
#  Epoch: 861. Mean Return: 5.7. Mean Length: 5.59
#  Epoch: 871. Mean Return: 8.9. Mean Length: 5.37
#  Epoch: 881. Mean Return: 5.5. Mean Length: 5.62
#  Epoch: 891. Mean Return: 6.2. Mean Length: 5.59
#  Epoch: 901. Mean Return: 8.4. Mean Length: 5.41
#  Epoch: 911. Mean Return: 9.0. Mean Length: 5.42
#  Epoch: 921. Mean Return: 11.6. Mean Length: 5.2
#  Epoch: 931. Mean Return: 6.6. Mean Length: 5.54
#  Epoch: 941. Mean Return: 7.3. Mean Length: 5.51
#  Epoch: 951. Mean Return: 8.7. Mean Length: 5.43
#  Epoch: 961. Mean Return: 6.6. Mean Length: 5.53
#  Epoch: 971. Mean Return: 9.6. Mean Length: 5.34
#  Epoch: 981. Mean Return: 8.8. Mean Length: 5.38
#  Epoch: 991. Mean Return: 6.9. Mean Length: 5.53
#  Epoch: 1001. Mean Return: 10.2. Mean Length: 5.26
#  Epoch: 1011. Mean Return: 8.3. Mean Length: 5.43
#  Epoch: 1021. Mean Return: 13.4. Mean Length: 5.02
#  Epoch: 1031. Mean Return: 8.8. Mean Length: 5.41
#  Epoch: 1041. Mean Return: 10.6. Mean Length: 5.26
#  Epoch: 1051. Mean Return: 7.3. Mean Length: 5.53
#  Epoch: 1061. Mean Return: 12.3. Mean Length: 5.12
#  Epoch: 1071. Mean Return: 8.1. Mean Length: 5.43
#  Epoch: 1081. Mean Return: 6.8. Mean Length: 5.53
#  Epoch: 1091. Mean Return: 11.1. Mean Length: 5.23
#  Epoch: 1101. Mean Return: 7.0. Mean Length: 5.5
#  Epoch: 1111. Mean Return: 8.9. Mean Length: 5.39
#  Epoch: 1121. Mean Return: 10.4. Mean Length: 5.25
#  Epoch: 1131. Mean Return: 8.9. Mean Length: 5.39
#  Epoch: 1141. Mean Return: 7.8. Mean Length: 5.49
#  Epoch: 1151. Mean Return: 10.9. Mean Length: 5.26
#  Epoch: 1161. Mean Return: 9.7. Mean Length: 5.34
#  Epoch: 1171. Mean Return: 7.4. Mean Length: 5.48
#  Epoch: 1181. Mean Return: 9.9. Mean Length: 5.3
#  Epoch: 1191. Mean Return: 10.7. Mean Length: 5.25
#  Epoch: 1201. Mean Return: 12.2. Mean Length: 5.11
#  Epoch: 1211. Mean Return: 15.2. Mean Length: 4.88
#  Epoch: 1221. Mean Return: 9.4. Mean Length: 5.36
#  Epoch: 1231. Mean Return: 12.3. Mean Length: 5.13
#  Epoch: 1241. Mean Return: 9.5. Mean Length: 5.35
#  Epoch: 1251. Mean Return: 9.5. Mean Length: 5.33
#  Epoch: 1261. Mean Return: 7.8. Mean Length: 5.45
#  Epoch: 1271. Mean Return: 8.5. Mean Length: 5.42
#  Epoch: 1281. Mean Return: 12.5. Mean Length: 5.12
#  Epoch: 1291. Mean Return: 13.2. Mean Length: 5.04
#  Epoch: 1301. Mean Return: 12.9. Mean Length: 5.04
#  Epoch: 1311. Mean Return: 8.9. Mean Length: 5.41
#  Epoch: 1321. Mean Return: 14.5. Mean Length: 4.99
#  Epoch: 1331. Mean Return: 10.4. Mean Length: 5.29
#  Epoch: 1341. Mean Return: 10.5. Mean Length: 5.25
#  Epoch: 1351. Mean Return: 11.1. Mean Length: 5.2
#  Epoch: 1361. Mean Return: 10.6. Mean Length: 5.27
#  Epoch: 1371. Mean Return: 9.3. Mean Length: 5.35
#  Epoch: 1381. Mean Return: 12.2. Mean Length: 5.11
#  Epoch: 1391. Mean Return: 11.1. Mean Length: 5.24
#  Epoch: 1401. Mean Return: 9.3. Mean Length: 5.32
#  Epoch: 1411. Mean Return: 15.4. Mean Length: 4.88
#  Epoch: 1421. Mean Return: 12.6. Mean Length: 5.1
#  Epoch: 1431. Mean Return: 13.0. Mean Length: 5.07
#  Epoch: 1441. Mean Return: 11.1. Mean Length: 5.2
#  Epoch: 1451. Mean Return: 10.4. Mean Length: 5.28
#  Epoch: 1461. Mean Return: 12.8. Mean Length: 5.08
#  Epoch: 1471. Mean Return: 12.4. Mean Length: 5.11
#  Epoch: 1481. Mean Return: 12.2. Mean Length: 5.14
#  Epoch: 1491. Mean Return: 14.1. Mean Length: 5.02
#  Epoch: 1501. Mean Return: 14.5. Mean Length: 4.94
#  Epoch: 1511. Mean Return: 15.1. Mean Length: 4.94
#  Epoch: 1521. Mean Return: 15.5. Mean Length: 4.86
#  Epoch: 1531. Mean Return: 10.6. Mean Length: 5.24
#  Epoch: 1541. Mean Return: 12.8. Mean Length: 5.1
#  Epoch: 1551. Mean Return: 13.2. Mean Length: 5.01
#  Epoch: 1561. Mean Return: 9.7. Mean Length: 5.35
#  Epoch: 1571. Mean Return: 15.0. Mean Length: 4.88
#  Epoch: 1581. Mean Return: 14.8. Mean Length: 4.93
#  Epoch: 1591. Mean Return: 14.7. Mean Length: 4.96
#  Epoch: 1601. Mean Return: 13.6. Mean Length: 5.03
#  Epoch: 1611. Mean Return: 14.6. Mean Length: 4.93
#  Epoch: 1621. Mean Return: 20.1. Mean Length: 4.5
#  Epoch: 1631. Mean Return: 16.6. Mean Length: 4.76
#  Epoch: 1641. Mean Return: 12.7. Mean Length: 5.07
#  Epoch: 1651. Mean Return: 11.3. Mean Length: 5.16
#  Epoch: 1661. Mean Return: 19.4. Mean Length: 4.54
#  Epoch: 1671. Mean Return: 18.3. Mean Length: 4.62
#  Epoch: 1681. Mean Return: 13.4. Mean Length: 5.01
#  Epoch: 1691. Mean Return: 14.5. Mean Length: 4.9
#  Epoch: 1701. Mean Return: 19.4. Mean Length: 4.57
#  Epoch: 1711. Mean Return: 13.9. Mean Length: 4.97
#  Epoch: 1721. Mean Return: 17.0. Mean Length: 4.72
#  Epoch: 1731. Mean Return: 18.1. Mean Length: 4.67
#  Epoch: 1741. Mean Return: 14.7. Mean Length: 4.89
#  Epoch: 1751. Mean Return: 19.5. Mean Length: 4.54
#  Epoch: 1761. Mean Return: 13.9. Mean Length: 4.95
#  Epoch: 1771. Mean Return: 10.9. Mean Length: 5.18
#  Epoch: 1781. Mean Return: 13.7. Mean Length: 4.99
#  Epoch: 1791. Mean Return: 13.2. Mean Length: 4.99
#  Epoch: 1801. Mean Return: 15.9. Mean Length: 4.8
#  Epoch: 1811. Mean Return: 16.4. Mean Length: 4.77
#  Epoch: 1821. Mean Return: 15.0. Mean Length: 4.89
#  Epoch: 1831. Mean Return: 16.8. Mean Length: 4.75
#  Epoch: 1841. Mean Return: 18.5. Mean Length: 4.62
#  Epoch: 1851. Mean Return: 13.2. Mean Length: 5.06
#  Epoch: 1861. Mean Return: 14.7. Mean Length: 4.88
#  Epoch: 1871. Mean Return: 17.6. Mean Length: 4.68
#  Epoch: 1881. Mean Return: 19.3. Mean Length: 4.55
#  Epoch: 1891. Mean Return: 17.4. Mean Length: 4.67
#  Epoch: 1901. Mean Return: 19.3. Mean Length: 4.55
#  Epoch: 1911. Mean Return: 17.9. Mean Length: 4.66
#  Epoch: 1921. Mean Return: 16.8. Mean Length: 4.77
#  Epoch: 1931. Mean Return: 17.5. Mean Length: 4.69
#  Epoch: 1941. Mean Return: 21.5. Mean Length: 4.33
#  Epoch: 1951. Mean Return: 17.4. Mean Length: 4.65
#  Epoch: 1961. Mean Return: 19.5. Mean Length: 4.52
#  Epoch: 1971. Mean Return: 15.9. Mean Length: 4.82
#  Epoch: 1981. Mean Return: 20.0. Mean Length: 4.48
#  Epoch: 1991. Mean Return: 20.4. Mean Length: 4.46
#  Epoch: 2001. Mean Return: 19.1. Mean Length: 4.55
#  Epoch: 2011. Mean Return: 20.9. Mean Length: 4.44
#  Epoch: 2021. Mean Return: 19.5. Mean Length: 4.59
#  Epoch: 2031. Mean Return: 19.7. Mean Length: 4.52
#  Epoch: 2041. Mean Return: 21.2. Mean Length: 4.38
#  Epoch: 2051. Mean Return: 20.7. Mean Length: 4.43
#  Epoch: 2061. Mean Return: 20.4. Mean Length: 4.46
#  Epoch: 2071. Mean Return: 18.5. Mean Length: 4.61
#  Epoch: 2081. Mean Return: 17.2. Mean Length: 4.69
#  Epoch: 2091. Mean Return: 23.7. Mean Length: 4.2
#  Epoch: 2101. Mean Return: 19.1. Mean Length: 4.55
#  Epoch: 2111. Mean Return: 18.0. Mean Length: 4.66
#  Epoch: 2121. Mean Return: 19.0. Mean Length: 4.57
#  Epoch: 2131. Mean Return: 18.4. Mean Length: 4.62
#  Epoch: 2141. Mean Return: 22.0. Mean Length: 4.33
#  Epoch: 2151. Mean Return: 22.2. Mean Length: 4.3
#  Epoch: 2161. Mean Return: 21.0. Mean Length: 4.39
#  Epoch: 2171. Mean Return: 16.9. Mean Length: 4.72
#  Epoch: 2181. Mean Return: 18.9. Mean Length: 4.59
#  Epoch: 2191. Mean Return: 21.2. Mean Length: 4.4
#  Epoch: 2201. Mean Return: 25.1. Mean Length: 4.08
#  Epoch: 2211. Mean Return: 22.6. Mean Length: 4.27
#  Epoch: 2221. Mean Return: 22.7. Mean Length: 4.29
#  Epoch: 2231. Mean Return: 18.1. Mean Length: 4.62
#  Epoch: 2241. Mean Return: 17.3. Mean Length: 4.71
#  Epoch: 2251. Mean Return: 20.6. Mean Length: 4.42
#  Epoch: 2261. Mean Return: 25.2. Mean Length: 4.08
#  Epoch: 2271. Mean Return: 23.0. Mean Length: 4.23
#  Epoch: 2281. Mean Return: 21.6. Mean Length: 4.34
#  Epoch: 2291. Mean Return: 21.6. Mean Length: 4.37
#  Epoch: 2301. Mean Return: 28.4. Mean Length: 3.84
#  Epoch: 2311. Mean Return: 17.4. Mean Length: 4.71
#  Epoch: 2321. Mean Return: 22.8. Mean Length: 4.27
#  Epoch: 2331. Mean Return: 22.3. Mean Length: 4.3
#  Epoch: 2341. Mean Return: 25.7. Mean Length: 4.0
#  Epoch: 2351. Mean Return: 22.0. Mean Length: 4.34
#  Epoch: 2361. Mean Return: 22.2. Mean Length: 4.33
#  Epoch: 2371. Mean Return: 22.5. Mean Length: 4.28
#  Epoch: 2381. Mean Return: 21.5. Mean Length: 4.36
#  Epoch: 2391. Mean Return: 21.8. Mean Length: 4.35
#  Epoch: 2401. Mean Return: 24.8. Mean Length: 4.14
#  Epoch: 2411. Mean Return: 19.4. Mean Length: 4.54
#  Epoch: 2421. Mean Return: 24.0. Mean Length: 4.17
#  Epoch: 2431. Mean Return: 21.1. Mean Length: 4.41
#  Epoch: 2441. Mean Return: 20.6. Mean Length: 4.41
#  Epoch: 2451. Mean Return: 23.3. Mean Length: 4.19
#  Epoch: 2461. Mean Return: 26.4. Mean Length: 3.97
#  Epoch: 2471. Mean Return: 24.1. Mean Length: 4.14
#  Epoch: 2481. Mean Return: 22.5. Mean Length: 4.31
#  Epoch: 2491. Mean Return: 21.8. Mean Length: 4.36
#  Epoch: 2501. Mean Return: 20.2. Mean Length: 4.47
#  Epoch: 2511. Mean Return: 24.1. Mean Length: 4.15
#  Epoch: 2521. Mean Return: 21.5. Mean Length: 4.33
#  Epoch: 2531. Mean Return: 25.0. Mean Length: 4.07
#  Epoch: 2541. Mean Return: 24.8. Mean Length: 4.11
#  Epoch: 2551. Mean Return: 22.0. Mean Length: 4.32
#  Epoch: 2561. Mean Return: 24.0. Mean Length: 4.17
#  Epoch: 2571. Mean Return: 22.3. Mean Length: 4.3
#  Epoch: 2581. Mean Return: 22.8. Mean Length: 4.24
#  Epoch: 2591. Mean Return: 23.7. Mean Length: 4.19
#  Epoch: 2601. Mean Return: 22.1. Mean Length: 4.28
#  Epoch: 2611. Mean Return: 23.6. Mean Length: 4.23
#  Epoch: 2621. Mean Return: 23.4. Mean Length: 4.18
#  Epoch: 2631. Mean Return: 25.2. Mean Length: 4.09
#  Epoch: 2641. Mean Return: 30.4. Mean Length: 3.65
#  Epoch: 2651. Mean Return: 22.2. Mean Length: 4.3
#  Epoch: 2661. Mean Return: 24.9. Mean Length: 4.08
#  Epoch: 2671. Mean Return: 24.3. Mean Length: 4.11
#  Epoch: 2681. Mean Return: 24.5. Mean Length: 4.12
#  Epoch: 2691. Mean Return: 24.5. Mean Length: 4.09
#  Epoch: 2701. Mean Return: 29.3. Mean Length: 3.75
#  Epoch: 2711. Mean Return: 26.9. Mean Length: 3.94
#  Epoch: 2721. Mean Return: 24.2. Mean Length: 4.17
#  Epoch: 2731. Mean Return: 22.4. Mean Length: 4.29
#  Epoch: 2741. Mean Return: 24.9. Mean Length: 4.12
#  Epoch: 2751. Mean Return: 23.1. Mean Length: 4.26
#  Epoch: 2761. Mean Return: 27.3. Mean Length: 3.89
#  Epoch: 2771. Mean Return: 26.0. Mean Length: 4.02
#  Epoch: 2781. Mean Return: 27.1. Mean Length: 3.9
#  Epoch: 2791. Mean Return: 21.6. Mean Length: 4.37
#  Epoch: 2801. Mean Return: 25.6. Mean Length: 4.04
#  Epoch: 2811. Mean Return: 26.7. Mean Length: 3.95
#  Epoch: 2821. Mean Return: 28.4. Mean Length: 3.82
#  Epoch: 2831. Mean Return: 29.4. Mean Length: 3.74
#  Epoch: 2841. Mean Return: 24.2. Mean Length: 4.17
#  Epoch: 2851. Mean Return: 26.3. Mean Length: 3.99
#  Epoch: 2861. Mean Return: 30.7. Mean Length: 3.64
#  Epoch: 2871. Mean Return: 26.6. Mean Length: 3.96
#  Epoch: 2881. Mean Return: 30.3. Mean Length: 3.68
#  Epoch: 2891. Mean Return: 29.4. Mean Length: 3.72
#  Epoch: 2901. Mean Return: 26.7. Mean Length: 3.95
#  Epoch: 2911. Mean Return: 28.7. Mean Length: 3.78
#  Epoch: 2921. Mean Return: 25.0. Mean Length: 4.07
#  Epoch: 2931. Mean Return: 24.3. Mean Length: 4.14
#  Epoch: 2941. Mean Return: 27.9. Mean Length: 3.86
#  Epoch: 2951. Mean Return: 24.3. Mean Length: 4.13
#  Epoch: 2961. Mean Return: 29.8. Mean Length: 3.71
#  Epoch: 2971. Mean Return: 29.5. Mean Length: 3.72
#  Epoch: 2981. Mean Return: 25.9. Mean Length: 4.01
#  Epoch: 2991. Mean Return: 28.8. Mean Length: 3.76
#  Epoch: 3001. Mean Return: 28.8. Mean Length: 3.79
#  Epoch: 3011. Mean Return: 22.9. Mean Length: 4.25
#  Epoch: 3021. Mean Return: 30.9. Mean Length: 3.61
#  Epoch: 3031. Mean Return: 25.3. Mean Length: 4.05
#  Epoch: 3041. Mean Return: 26.9. Mean Length: 3.93
#  Epoch: 3051. Mean Return: 27.6. Mean Length: 3.85
#  Epoch: 3061. Mean Return: 29.1. Mean Length: 3.77
#  Epoch: 3071. Mean Return: 27.8. Mean Length: 3.85
#  Epoch: 3081. Mean Return: 25.2. Mean Length: 4.04
#  Epoch: 3091. Mean Return: 30.3. Mean Length: 3.66
#  Epoch: 3101. Mean Return: 23.7. Mean Length: 4.17
#  Epoch: 3111. Mean Return: 27.2. Mean Length: 3.9
#  Epoch: 3121. Mean Return: 27.2. Mean Length: 3.9
#  Epoch: 3131. Mean Return: 32.8. Mean Length: 3.48
#  Epoch: 3141. Mean Return: 28.5. Mean Length: 3.81
#  Epoch: 3151. Mean Return: 25.2. Mean Length: 4.07
#  Epoch: 3161. Mean Return: 23.7. Mean Length: 4.19
#  Epoch: 3171. Mean Return: 26.2. Mean Length: 3.99
#  Epoch: 3181. Mean Return: 28.3. Mean Length: 3.81
#  Epoch: 3191. Mean Return: 27.7. Mean Length: 3.87
#  Epoch: 3201. Mean Return: 28.1. Mean Length: 3.82
#  Epoch: 3211. Mean Return: 27.8. Mean Length: 3.85
#  Epoch: 3221. Mean Return: 26.3. Mean Length: 3.97
#  Epoch: 3231. Mean Return: 30.1. Mean Length: 3.69
#  Epoch: 3241. Mean Return: 32.9. Mean Length: 3.44
#  Epoch: 3251. Mean Return: 29.2. Mean Length: 3.72
#  Epoch: 3261. Mean Return: 30.0. Mean Length: 3.67
#  Epoch: 3271. Mean Return: 23.1. Mean Length: 4.24
#  Epoch: 3281. Mean Return: 33.5. Mean Length: 3.39
#  Epoch: 3291. Mean Return: 30.4. Mean Length: 3.65
#  Epoch: 3301. Mean Return: 29.9. Mean Length: 3.69
#  Epoch: 3311. Mean Return: 24.0. Mean Length: 4.16
#  Epoch: 3321. Mean Return: 31.0. Mean Length: 3.63
#  Epoch: 3331. Mean Return: 29.0. Mean Length: 3.78
#  Epoch: 3341. Mean Return: 33.5. Mean Length: 3.41
#  Epoch: 3351. Mean Return: 29.7. Mean Length: 3.72
#  Epoch: 3361. Mean Return: 30.2. Mean Length: 3.7
#  Epoch: 3371. Mean Return: 31.4. Mean Length: 3.56
#  Epoch: 3381. Mean Return: 30.9. Mean Length: 3.62
#  Epoch: 3391. Mean Return: 33.9. Mean Length: 3.36
#  Epoch: 3401. Mean Return: 30.2. Mean Length: 3.65
#  Epoch: 3411. Mean Return: 33.6. Mean Length: 3.41
#  Epoch: 3421. Mean Return: 29.2. Mean Length: 3.75
#  Epoch: 3431. Mean Return: 28.7. Mean Length: 3.8
#  Epoch: 3441. Mean Return: 29.0. Mean Length: 3.76
#  Epoch: 3451. Mean Return: 29.2. Mean Length: 3.75
#  Epoch: 3461. Mean Return: 25.1. Mean Length: 4.09
#  Epoch: 3471. Mean Return: 31.8. Mean Length: 3.54
#  Epoch: 3481. Mean Return: 31.0. Mean Length: 3.63
#  Epoch: 3491. Mean Return: 29.1. Mean Length: 3.76
#  Epoch: 3501. Mean Return: 30.3. Mean Length: 3.67
#  Epoch: 3511. Mean Return: 29.9. Mean Length: 3.68
#  Epoch: 3521. Mean Return: 31.1. Mean Length: 3.58
#  Epoch: 3531. Mean Return: 33.4. Mean Length: 3.42
#  Epoch: 3541. Mean Return: 32.1. Mean Length: 3.55
#  Epoch: 3551. Mean Return: 33.0. Mean Length: 3.46
#  Epoch: 3561. Mean Return: 34.1. Mean Length: 3.37
#  Epoch: 3571. Mean Return: 33.7. Mean Length: 3.39
#  Epoch: 3581. Mean Return: 30.9. Mean Length: 3.63
#  Epoch: 3591. Mean Return: 29.5. Mean Length: 3.71
#  Epoch: 3601. Mean Return: 33.7. Mean Length: 3.38
#  Epoch: 3611. Mean Return: 31.9. Mean Length: 3.54
#  Epoch: 3621. Mean Return: 33.9. Mean Length: 3.41
#  Epoch: 3631. Mean Return: 30.7. Mean Length: 3.63
#  Epoch: 3641. Mean Return: 32.5. Mean Length: 3.46
#  Epoch: 3651. Mean Return: 32.2. Mean Length: 3.49
#  Epoch: 3661. Mean Return: 35.3. Mean Length: 3.25
#  Epoch: 3671. Mean Return: 32.3. Mean Length: 3.51
#  Epoch: 3681. Mean Return: 31.6. Mean Length: 3.57
#  Epoch: 3691. Mean Return: 35.4. Mean Length: 3.21
#  Epoch: 3701. Mean Return: 27.7. Mean Length: 3.84
#  Epoch: 3711. Mean Return: 32.8. Mean Length: 3.43
#  Epoch: 3721. Mean Return: 34.7. Mean Length: 3.32
#  Epoch: 3731. Mean Return: 34.3. Mean Length: 3.33
#  Epoch: 3741. Mean Return: 35.1. Mean Length: 3.27
#  Epoch: 3751. Mean Return: 33.6. Mean Length: 3.41
#  Epoch: 3761. Mean Return: 28.6. Mean Length: 3.77
#  Epoch: 3771. Mean Return: 31.9. Mean Length: 3.54
#  Epoch: 3781. Mean Return: 31.3. Mean Length: 3.58
#  Epoch: 3791. Mean Return: 36.1. Mean Length: 3.19
#  Epoch: 3801. Mean Return: 33.9. Mean Length: 3.34
#  Epoch: 3811. Mean Return: 35.3. Mean Length: 3.24
#  Epoch: 3821. Mean Return: 26.5. Mean Length: 3.94
#  Epoch: 3831. Mean Return: 33.4. Mean Length: 3.41
#  Epoch: 3841. Mean Return: 33.7. Mean Length: 3.37
#  Epoch: 3851. Mean Return: 33.4. Mean Length: 3.42
#  Epoch: 3861. Mean Return: 31.9. Mean Length: 3.51
#  Epoch: 3871. Mean Return: 32.0. Mean Length: 3.54
#  Epoch: 3881. Mean Return: 35.7. Mean Length: 3.23
#  Epoch: 3891. Mean Return: 29.7. Mean Length: 3.71
#  Epoch: 3901. Mean Return: 33.4. Mean Length: 3.41
#  Epoch: 3911. Mean Return: 35.2. Mean Length: 3.28
#  Epoch: 3921. Mean Return: 36.7. Mean Length: 3.16
#  Epoch: 3931. Mean Return: 32.0. Mean Length: 3.52
#  Epoch: 3941. Mean Return: 30.7. Mean Length: 3.64
#  Epoch: 3951. Mean Return: 33.9. Mean Length: 3.39
#  Epoch: 3961. Mean Return: 35.8. Mean Length: 3.25
#  Epoch: 3971. Mean Return: 36.7. Mean Length: 3.15
#  Epoch: 3981. Mean Return: 35.1. Mean Length: 3.28
#  Epoch: 3991. Mean Return: 34.4. Mean Length: 3.35
#  Epoch: 4001. Mean Return: 31.8. Mean Length: 3.52
#  Epoch: 4011. Mean Return: 32.7. Mean Length: 3.46
#  Epoch: 4021. Mean Return: 34.3. Mean Length: 3.35
#  Epoch: 4031. Mean Return: 33.7. Mean Length: 3.38
#  Epoch: 4041. Mean Return: 33.3. Mean Length: 3.42
#  Epoch: 4051. Mean Return: 33.8. Mean Length: 3.38
#  Epoch: 4061. Mean Return: 34.6. Mean Length: 3.29
#  Epoch: 4071. Mean Return: 32.1. Mean Length: 3.51
#  Epoch: 4081. Mean Return: 33.8. Mean Length: 3.39
#  Epoch: 4091. Mean Return: 35.6. Mean Length: 3.24
#  Epoch: 4101. Mean Return: 34.0. Mean Length: 3.35
#  Epoch: 4111. Mean Return: 36.4. Mean Length: 3.17
#  Epoch: 4121. Mean Return: 35.8. Mean Length: 3.21
#  Epoch: 4131. Mean Return: 34.0. Mean Length: 3.38
#  Epoch: 4141. Mean Return: 32.3. Mean Length: 3.49
#  Epoch: 4151. Mean Return: 33.7. Mean Length: 3.39
#  Epoch: 4161. Mean Return: 36.8. Mean Length: 3.13
#  Epoch: 4171. Mean Return: 35.4. Mean Length: 3.26
#  Epoch: 4181. Mean Return: 32.3. Mean Length: 3.53
#  Epoch: 4191. Mean Return: 28.5. Mean Length: 3.84
#  Epoch: 4201. Mean Return: 31.3. Mean Length: 3.6
#  Epoch: 4211. Mean Return: 27.5. Mean Length: 3.91
#  Epoch: 4221. Mean Return: 35.4. Mean Length: 3.25
#  Epoch: 4231. Mean Return: 29.1. Mean Length: 3.82
#  Epoch: 4241. Mean Return: 30.1. Mean Length: 3.68
#  Epoch: 4251. Mean Return: 29.6. Mean Length: 3.74
#  Epoch: 4261. Mean Return: 34.3. Mean Length: 3.36
#  Epoch: 4271. Mean Return: 30.8. Mean Length: 3.63
#  Epoch: 4281. Mean Return: 35.5. Mean Length: 3.25
#  Epoch: 4291. Mean Return: 32.5. Mean Length: 3.5
#  Epoch: 4301. Mean Return: 32.7. Mean Length: 3.48
#  Epoch: 4311. Mean Return: 33.5. Mean Length: 3.41
#  Epoch: 4321. Mean Return: 33.6. Mean Length: 3.45
#  Epoch: 4331. Mean Return: 32.9. Mean Length: 3.47
#  Epoch: 4341. Mean Return: 32.0. Mean Length: 3.55
#  Epoch: 4351. Mean Return: 35.0. Mean Length: 3.32
#  Epoch: 4361. Mean Return: 31.2. Mean Length: 3.59
#  Epoch: 4371. Mean Return: 31.7. Mean Length: 3.57
#  Epoch: 4381. Mean Return: 34.5. Mean Length: 3.32
#  Epoch: 4391. Mean Return: 35.2. Mean Length: 3.27
#  Epoch: 4401. Mean Return: 36.7. Mean Length: 3.16
#  Epoch: 4411. Mean Return: 32.2. Mean Length: 3.52
#  Epoch: 4421. Mean Return: 33.9. Mean Length: 3.37
#  Epoch: 4431. Mean Return: 31.5. Mean Length: 3.58
#  Epoch: 4441. Mean Return: 33.8. Mean Length: 3.38
#  Epoch: 4451. Mean Return: 32.9. Mean Length: 3.47
#  Epoch: 4461. Mean Return: 33.7. Mean Length: 3.4
#  Epoch: 4471. Mean Return: 38.1. Mean Length: 3.05
#  Epoch: 4481. Mean Return: 35.7. Mean Length: 3.26
#  Epoch: 4491. Mean Return: 34.4. Mean Length: 3.34
#  Epoch: 4501. Mean Return: 35.5. Mean Length: 3.26
#  Epoch: 4511. Mean Return: 33.1. Mean Length: 3.45
#  Epoch: 4521. Mean Return: 34.8. Mean Length: 3.3
#  Epoch: 4531. Mean Return: 36.2. Mean Length: 3.21
#  Epoch: 4541. Mean Return: 32.6. Mean Length: 3.49
#  Epoch: 4551. Mean Return: 34.3. Mean Length: 3.33
#  Epoch: 4561. Mean Return: 35.6. Mean Length: 3.25
#  Epoch: 4571. Mean Return: 33.7. Mean Length: 3.41
#  Epoch: 4581. Mean Return: 29.0. Mean Length: 3.77
#  Epoch: 4591. Mean Return: 35.0. Mean Length: 3.3
#  Epoch: 4601. Mean Return: 31.4. Mean Length: 3.58
#  Epoch: 4611. Mean Return: 30.9. Mean Length: 3.62
#  Epoch: 4621. Mean Return: 34.7. Mean Length: 3.33
#  Epoch: 4631. Mean Return: 33.9. Mean Length: 3.37
#  Epoch: 4641. Mean Return: 34.3. Mean Length: 3.35
#  Epoch: 4651. Mean Return: 34.2. Mean Length: 3.33
#  Epoch: 4661. Mean Return: 36.8. Mean Length: 3.14
#  Epoch: 4671. Mean Return: 35.3. Mean Length: 3.28
#  Epoch: 4681. Mean Return: 31.4. Mean Length: 3.58
#  Epoch: 4691. Mean Return: 32.6. Mean Length: 3.49
#  Epoch: 4701. Mean Return: 35.9. Mean Length: 3.26
#  Epoch: 4711. Mean Return: 38.0. Mean Length: 3.06
#  Epoch: 4721. Mean Return: 33.9. Mean Length: 3.38
#  Epoch: 4731. Mean Return: 33.7. Mean Length: 3.39
#  Epoch: 4741. Mean Return: 33.2. Mean Length: 3.45
#  Epoch: 4751. Mean Return: 33.1. Mean Length: 3.47
#  Epoch: 4761. Mean Return: 31.9. Mean Length: 3.54
#  Epoch: 4771. Mean Return: 36.5. Mean Length: 3.15
#  Epoch: 4781. Mean Return: 34.8. Mean Length: 3.3
#  Epoch: 4791. Mean Return: 34.7. Mean Length: 3.31
#  Epoch: 4801. Mean Return: 35.8. Mean Length: 3.25
#  Epoch: 4811. Mean Return: 36.6. Mean Length: 3.15
#  Epoch: 4821. Mean Return: 35.3. Mean Length: 3.24
#  Epoch: 4831. Mean Return: 36.0. Mean Length: 3.21
#  Epoch: 4841. Mean Return: 37.2. Mean Length: 3.11
#  Epoch: 4851. Mean Return: 35.6. Mean Length: 3.26
#  Epoch: 4861. Mean Return: 36.3. Mean Length: 3.2
#  Epoch: 4871. Mean Return: 35.3. Mean Length: 3.26
#  Epoch: 4881. Mean Return: 37.0. Mean Length: 3.12
#  Epoch: 4891. Mean Return: 41.6. Mean Length: 2.78
#  Epoch: 4901. Mean Return: 36.1. Mean Length: 3.22
#  Epoch: 4911. Mean Return: 38.0. Mean Length: 3.07
#  Epoch: 4921. Mean Return: 34.8. Mean Length: 3.3
#  Epoch: 4931. Mean Return: 37.3. Mean Length: 3.1
#  Epoch: 4941. Mean Return: 37.2. Mean Length: 3.12
#  Epoch: 4951. Mean Return: 35.5. Mean Length: 3.25
#  Epoch: 4961. Mean Return: 34.9. Mean Length: 3.3
#  Epoch: 4971. Mean Return: 33.0. Mean Length: 3.45
#  Epoch: 4981. Mean Return: 35.2. Mean Length: 3.29
#  Epoch: 4991. Mean Return: 34.6. Mean Length: 3.31
#  Epoch: 5001. Mean Return: 39.2. Mean Length: 2.95
#  Epoch: 5011. Mean Return: 33.9. Mean Length: 3.37
#  Epoch: 5021. Mean Return: 35.4. Mean Length: 3.28
#  Epoch: 5031. Mean Return: 33.3. Mean Length: 3.41
#  Epoch: 5041. Mean Return: 35.1. Mean Length: 3.29
#  Epoch: 5051. Mean Return: 34.7. Mean Length: 3.3
#  Epoch: 5061. Mean Return: 39.3. Mean Length: 2.93
#  Epoch: 5071. Mean Return: 35.5. Mean Length: 3.26
#  Epoch: 5081. Mean Return: 34.0. Mean Length: 3.36
#  Epoch: 5091. Mean Return: 35.0. Mean Length: 3.27
#  Epoch: 5101. Mean Return: 37.7. Mean Length: 3.09
#  Epoch: 5111. Mean Return: 37.5. Mean Length: 3.08
#  Epoch: 5121. Mean Return: 37.8. Mean Length: 3.07
#  Epoch: 5131. Mean Return: 36.8. Mean Length: 3.12
#  Epoch: 5141. Mean Return: 37.9. Mean Length: 3.06
#  Epoch: 5151. Mean Return: 37.5. Mean Length: 3.09
#  Epoch: 5161. Mean Return: 35.6. Mean Length: 3.24
#  Epoch: 5171. Mean Return: 37.8. Mean Length: 3.09
#  Epoch: 5181. Mean Return: 35.7. Mean Length: 3.21
#  Epoch: 5191. Mean Return: 35.9. Mean Length: 3.22
#  Epoch: 5201. Mean Return: 37.2. Mean Length: 3.12
#  Epoch: 5211. Mean Return: 34.2. Mean Length: 3.34
#  Epoch: 5221. Mean Return: 35.8. Mean Length: 3.23
#  Epoch: 5231. Mean Return: 36.0. Mean Length: 3.2
#  Epoch: 5241. Mean Return: 32.1. Mean Length: 3.53
#  Epoch: 5251. Mean Return: 37.8. Mean Length: 3.08
#  Epoch: 5261. Mean Return: 36.7. Mean Length: 3.17
#  Epoch: 5271. Mean Return: 39.5. Mean Length: 2.94
#  Epoch: 5281. Mean Return: 37.0. Mean Length: 3.15
#  Epoch: 5291. Mean Return: 33.5. Mean Length: 3.4
#  Epoch: 5301. Mean Return: 36.7. Mean Length: 3.17
#  Epoch: 5311. Mean Return: 35.2. Mean Length: 3.31
#  Epoch: 5321. Mean Return: 40.7. Mean Length: 2.83
#  Epoch: 5331. Mean Return: 37.0. Mean Length: 3.12
#  Epoch: 5341. Mean Return: 34.8. Mean Length: 3.29
#  Epoch: 5351. Mean Return: 34.7. Mean Length: 3.3
#  Epoch: 5361. Mean Return: 36.4. Mean Length: 3.17
#  Epoch: 5371. Mean Return: 36.5. Mean Length: 3.15
#  Epoch: 5381. Mean Return: 37.7. Mean Length: 3.08
#  Epoch: 5391. Mean Return: 39.8. Mean Length: 2.9
#  Epoch: 5401. Mean Return: 37.2. Mean Length: 3.11
#  Epoch: 5411. Mean Return: 36.7. Mean Length: 3.16
#  Epoch: 5421. Mean Return: 35.0. Mean Length: 3.31
#  Epoch: 5431. Mean Return: 34.5. Mean Length: 3.31
#  Epoch: 5441. Mean Return: 30.5. Mean Length: 3.67
#  Epoch: 5451. Mean Return: 37.8. Mean Length: 3.05
#  Epoch: 5461. Mean Return: 34.8. Mean Length: 3.3
#  Epoch: 5471. Mean Return: 36.0. Mean Length: 3.18
#  Epoch: 5481. Mean Return: 35.2. Mean Length: 3.3
#  Epoch: 5491. Mean Return: 35.6. Mean Length: 3.24
#  Epoch: 5501. Mean Return: 36.2. Mean Length: 3.2
#  Epoch: 5511. Mean Return: 35.7. Mean Length: 3.22
#  Epoch: 5521. Mean Return: 34.4. Mean Length: 3.34
#  Epoch: 5531. Mean Return: 37.6. Mean Length: 3.06
#  Epoch: 5541. Mean Return: 36.6. Mean Length: 3.17
#  Epoch: 5551. Mean Return: 37.3. Mean Length: 3.1
#  Epoch: 5561. Mean Return: 36.8. Mean Length: 3.12
#  Epoch: 5571. Mean Return: 32.8. Mean Length: 3.46
#  Epoch: 5581. Mean Return: 39.4. Mean Length: 2.93
#  Epoch: 5591. Mean Return: 36.6. Mean Length: 3.13
#  Epoch: 5601. Mean Return: 33.6. Mean Length: 3.41
#  Epoch: 5611. Mean Return: 36.5. Mean Length: 3.15
#  Epoch: 5621. Mean Return: 34.8. Mean Length: 3.32
#  Epoch: 5631. Mean Return: 38.1. Mean Length: 3.05
#  Epoch: 5641. Mean Return: 34.9. Mean Length: 3.28
#  Epoch: 5651. Mean Return: 36.6. Mean Length: 3.16
#  Epoch: 5661. Mean Return: 35.1. Mean Length: 3.26
#  Epoch: 5671. Mean Return: 38.2. Mean Length: 3.04
#  Epoch: 5681. Mean Return: 36.5. Mean Length: 3.17
#  Epoch: 5691. Mean Return: 36.4. Mean Length: 3.2
#  Epoch: 5701. Mean Return: 36.5. Mean Length: 3.15
#  Epoch: 5711. Mean Return: 36.4. Mean Length: 3.18
#  Epoch: 5721. Mean Return: 35.0. Mean Length: 3.28
#  Epoch: 5731. Mean Return: 34.3. Mean Length: 3.34
#  Epoch: 5741. Mean Return: 37.6. Mean Length: 3.1
#  Epoch: 5751. Mean Return: 34.2. Mean Length: 3.35
#  Epoch: 5761. Mean Return: 38.0. Mean Length: 3.05
#  Epoch: 5771. Mean Return: 38.0. Mean Length: 3.05
#  Epoch: 5781. Mean Return: 36.5. Mean Length: 3.15
#  Epoch: 5791. Mean Return: 33.0. Mean Length: 3.46
#  Epoch: 5801. Mean Return: 37.1. Mean Length: 3.11
#  Epoch: 5811. Mean Return: 37.2. Mean Length: 3.11
#  Epoch: 5821. Mean Return: 36.8. Mean Length: 3.14
#  Epoch: 5831. Mean Return: 39.2. Mean Length: 2.95
#  Epoch: 5841. Mean Return: 38.3. Mean Length: 3.02
#  Epoch: 5851. Mean Return: 37.6. Mean Length: 3.07
#  Epoch: 5861. Mean Return: 35.8. Mean Length: 3.22
#  Epoch: 5871. Mean Return: 32.5. Mean Length: 3.47
#  Epoch: 5881. Mean Return: 39.6. Mean Length: 2.94
#  Epoch: 5891. Mean Return: 37.1. Mean Length: 3.12
#  Epoch: 5901. Mean Return: 35.7. Mean Length: 3.24
#  Epoch: 5911. Mean Return: 40.5. Mean Length: 2.83
#  Epoch: 5921. Mean Return: 38.7. Mean Length: 3.0
#  Epoch: 5931. Mean Return: 36.0. Mean Length: 3.21
#  Epoch: 5941. Mean Return: 33.7. Mean Length: 3.4
#  Epoch: 5951. Mean Return: 35.5. Mean Length: 3.23
#  Epoch: 5961. Mean Return: 37.5. Mean Length: 3.08
#  Epoch: 5971. Mean Return: 37.2. Mean Length: 3.11
#  Epoch: 5981. Mean Return: 37.4. Mean Length: 3.07
#  Epoch: 5991. Mean Return: 39.9. Mean Length: 2.88
#  Epoch: 6001. Mean Return: 39.4. Mean Length: 2.93
#  Epoch: 6011. Mean Return: 37.1. Mean Length: 3.11
#  Epoch: 6021. Mean Return: 35.1. Mean Length: 3.26
#  Epoch: 6031. Mean Return: 39.2. Mean Length: 2.96
#  Epoch: 6041. Mean Return: 41.6. Mean Length: 2.75
#  Epoch: 6051. Mean Return: 38.4. Mean Length: 3.01
#  Epoch: 6061. Mean Return: 37.0. Mean Length: 3.09
#  Epoch: 6071. Mean Return: 39.4. Mean Length: 2.94
#  Epoch: 6081. Mean Return: 36.4. Mean Length: 3.15
#  Epoch: 6091. Mean Return: 36.1. Mean Length: 3.21
#  Epoch: 6101. Mean Return: 35.8. Mean Length: 3.21
#  Epoch: 6111. Mean Return: 36.2. Mean Length: 3.19
#  Epoch: 6121. Mean Return: 39.3. Mean Length: 2.93
#  Epoch: 6131. Mean Return: 33.9. Mean Length: 3.37
#  Epoch: 6141. Mean Return: 34.9. Mean Length: 3.28
#  Epoch: 6151. Mean Return: 37.7. Mean Length: 3.09
#  Epoch: 6161. Mean Return: 34.4. Mean Length: 3.33
#  Epoch: 6171. Mean Return: 39.8. Mean Length: 2.9
#  Epoch: 6181. Mean Return: 36.1. Mean Length: 3.2
#  Epoch: 6191. Mean Return: 39.5. Mean Length: 2.94
#  Epoch: 6201. Mean Return: 37.8. Mean Length: 3.06
#  Epoch: 6211. Mean Return: 35.9. Mean Length: 3.23
#  Epoch: 6221. Mean Return: 37.4. Mean Length: 3.08
#  Epoch: 6231. Mean Return: 33.7. Mean Length: 3.37
#  Epoch: 6241. Mean Return: 37.5. Mean Length: 3.08
#  Epoch: 6251. Mean Return: 37.3. Mean Length: 3.13
#  Epoch: 6261. Mean Return: 35.7. Mean Length: 3.24
#  Epoch: 6271. Mean Return: 39.6. Mean Length: 2.92
#  Epoch: 6281. Mean Return: 35.5. Mean Length: 3.26
#  Epoch: 6291. Mean Return: 37.8. Mean Length: 3.05
#  Epoch: 6301. Mean Return: 34.8. Mean Length: 3.3
#  Epoch: 6311. Mean Return: 36.9. Mean Length: 3.13
#  Epoch: 6321. Mean Return: 35.0. Mean Length: 3.29
#  Epoch: 6331. Mean Return: 35.7. Mean Length: 3.24
#  Epoch: 6341. Mean Return: 38.6. Mean Length: 2.99
#  Epoch: 6351. Mean Return: 35.9. Mean Length: 3.2
#  Epoch: 6361. Mean Return: 41.6. Mean Length: 2.76
#  Epoch: 6371. Mean Return: 40.9. Mean Length: 2.81
#  Epoch: 6381. Mean Return: 35.1. Mean Length: 3.27
#  Epoch: 6391. Mean Return: 37.2. Mean Length: 3.09
#  Epoch: 6401. Mean Return: 38.0. Mean Length: 3.03
#  Epoch: 6411. Mean Return: 38.5. Mean Length: 3.02
#  Epoch: 6421. Mean Return: 36.7. Mean Length: 3.16
#  Epoch: 6431. Mean Return: 37.4. Mean Length: 3.1
#  Epoch: 6441. Mean Return: 40.1. Mean Length: 2.86
#  Epoch: 6451. Mean Return: 34.3. Mean Length: 3.32
#  Epoch: 6461. Mean Return: 38.0. Mean Length: 3.07
#  Epoch: 6471. Mean Return: 37.8. Mean Length: 3.06
#  Epoch: 6481. Mean Return: 38.9. Mean Length: 2.98
#  Epoch: 6491. Mean Return: 39.6. Mean Length: 2.92
#  Epoch: 6501. Mean Return: 38.5. Mean Length: 3.0
#  Epoch: 6511. Mean Return: 37.5. Mean Length: 3.07
#  Epoch: 6521. Mean Return: 39.9. Mean Length: 2.91
#  Epoch: 6531. Mean Return: 37.7. Mean Length: 3.07
#  Epoch: 6541. Mean Return: 34.4. Mean Length: 3.32
#  Epoch: 6551. Mean Return: 36.5. Mean Length: 3.18
#  Epoch: 6561. Mean Return: 36.8. Mean Length: 3.15
#  Epoch: 6571. Mean Return: 38.0. Mean Length: 3.05
#  Epoch: 6581. Mean Return: 37.7. Mean Length: 3.06
#  Epoch: 6591. Mean Return: 36.1. Mean Length: 3.21
#  Epoch: 6601. Mean Return: 38.5. Mean Length: 2.98
#  Epoch: 6611. Mean Return: 35.3. Mean Length: 3.28
#  Epoch: 6621. Mean Return: 38.3. Mean Length: 3.02
#  Epoch: 6631. Mean Return: 35.6. Mean Length: 3.24
#  Epoch: 6641. Mean Return: 39.0. Mean Length: 2.97
#  Epoch: 6651. Mean Return: 39.0. Mean Length: 2.97
#  Epoch: 6661. Mean Return: 38.0. Mean Length: 3.06
#  Epoch: 6671. Mean Return: 34.2. Mean Length: 3.36
#  Epoch: 6681. Mean Return: 37.7. Mean Length: 3.06
#  Epoch: 6691. Mean Return: 40.7. Mean Length: 2.84
#  Epoch: 6701. Mean Return: 37.3. Mean Length: 3.11
#  Epoch: 6711. Mean Return: 38.6. Mean Length: 3.02
#  Epoch: 6721. Mean Return: 40.0. Mean Length: 2.9
#  Epoch: 6731. Mean Return: 39.0. Mean Length: 2.97
#  Epoch: 6741. Mean Return: 38.8. Mean Length: 2.98
#  Epoch: 6751. Mean Return: 37.5. Mean Length: 3.09
#  Epoch: 6761. Mean Return: 36.7. Mean Length: 3.16
#  Epoch: 6771. Mean Return: 35.1. Mean Length: 3.28
#  Epoch: 6781. Mean Return: 36.9. Mean Length: 3.14
#  Epoch: 6791. Mean Return: 38.8. Mean Length: 3.0
#  Epoch: 6801. Mean Return: 37.1. Mean Length: 3.12
#  Epoch: 6811. Mean Return: 37.9. Mean Length: 3.05
#  Epoch: 6821. Mean Return: 41.1. Mean Length: 2.82
#  Epoch: 6831. Mean Return: 37.8. Mean Length: 3.09
#  Epoch: 6841. Mean Return: 39.3. Mean Length: 2.96
#  Epoch: 6851. Mean Return: 36.4. Mean Length: 3.19
#  Epoch: 6861. Mean Return: 38.5. Mean Length: 3.01
#  Epoch: 6871. Mean Return: 37.9. Mean Length: 3.06
#  Epoch: 6881. Mean Return: 37.2. Mean Length: 3.1
#  Epoch: 6891. Mean Return: 38.8. Mean Length: 2.98
#  Epoch: 6901. Mean Return: 41.1. Mean Length: 2.8
#  Epoch: 6911. Mean Return: 36.9. Mean Length: 3.14
#  Epoch: 6921. Mean Return: 38.0. Mean Length: 3.06
#  Epoch: 6931. Mean Return: 37.8. Mean Length: 3.06
#  Epoch: 6941. Mean Return: 37.2. Mean Length: 3.13
#  Epoch: 6951. Mean Return: 39.9. Mean Length: 2.89
#  Epoch: 6961. Mean Return: 40.2. Mean Length: 2.87
#  Epoch: 6971. Mean Return: 38.6. Mean Length: 3.01
#  Epoch: 6981. Mean Return: 37.8. Mean Length: 3.07
#  Epoch: 6991. Mean Return: 35.6. Mean Length: 3.24
#  Epoch: 7001. Mean Return: 37.7. Mean Length: 3.08
#  Epoch: 7011. Mean Return: 40.3. Mean Length: 2.85
#  Epoch: 7021. Mean Return: 39.5. Mean Length: 2.92
#  Epoch: 7031. Mean Return: 40.1. Mean Length: 2.9
#  Epoch: 7041. Mean Return: 38.6. Mean Length: 3.01
#  Epoch: 7051. Mean Return: 41.2. Mean Length: 2.8
#  Epoch: 7061. Mean Return: 41.4. Mean Length: 2.78
#  Epoch: 7071. Mean Return: 39.1. Mean Length: 2.95
#  Epoch: 7081. Mean Return: 40.0. Mean Length: 2.9
#  Epoch: 7091. Mean Return: 40.0. Mean Length: 2.89
#  Epoch: 7101. Mean Return: 39.9. Mean Length: 2.91
#  Epoch: 7111. Mean Return: 39.6. Mean Length: 2.94
#  Epoch: 7121. Mean Return: 38.9. Mean Length: 3.0
#  Epoch: 7131. Mean Return: 39.1. Mean Length: 2.97
#  Epoch: 7141. Mean Return: 40.7. Mean Length: 2.82
#  Epoch: 7151. Mean Return: 38.6. Mean Length: 2.99
#  Epoch: 7161. Mean Return: 41.3. Mean Length: 2.77
#  Epoch: 7171. Mean Return: 37.0. Mean Length: 3.15
#  Epoch: 7181. Mean Return: 37.5. Mean Length: 3.09
#  Epoch: 7191. Mean Return: 40.2. Mean Length: 2.86
#  Epoch: 7201. Mean Return: 40.6. Mean Length: 2.86
#  Epoch: 7211. Mean Return: 39.0. Mean Length: 2.99
#  Epoch: 7221. Mean Return: 38.8. Mean Length: 2.97
#  Epoch: 7231. Mean Return: 42.0. Mean Length: 2.73
#  Epoch: 7241. Mean Return: 36.2. Mean Length: 3.17
#  Epoch: 7251. Mean Return: 40.2. Mean Length: 2.88
#  Epoch: 7261. Mean Return: 37.2. Mean Length: 3.14
#  Epoch: 7271. Mean Return: 41.1. Mean Length: 2.79
#  Epoch: 7281. Mean Return: 33.3. Mean Length: 3.44
#  Epoch: 7291. Mean Return: 39.2. Mean Length: 2.96
#  Epoch: 7301. Mean Return: 38.6. Mean Length: 2.98
#  Epoch: 7311. Mean Return: 39.2. Mean Length: 2.95
#  Epoch: 7321. Mean Return: 41.3. Mean Length: 2.78
#  Epoch: 7331. Mean Return: 39.0. Mean Length: 2.96
#  Epoch: 7341. Mean Return: 38.2. Mean Length: 3.03
#  Epoch: 7351. Mean Return: 42.0. Mean Length: 2.73
#  Epoch: 7361. Mean Return: 40.5. Mean Length: 2.85
#  Epoch: 7371. Mean Return: 40.3. Mean Length: 2.86
#  Epoch: 7381. Mean Return: 38.6. Mean Length: 3.01
#  Epoch: 7391. Mean Return: 40.4. Mean Length: 2.86
#  Epoch: 7401. Mean Return: 38.9. Mean Length: 2.97
#  Epoch: 7411. Mean Return: 39.3. Mean Length: 2.95
#  Epoch: 7421. Mean Return: 40.9. Mean Length: 2.84
#  Epoch: 7431. Mean Return: 38.1. Mean Length: 3.02
#  Epoch: 7441. Mean Return: 42.9. Mean Length: 2.66
#  Epoch: 7451. Mean Return: 37.2. Mean Length: 3.11
#  Epoch: 7461. Mean Return: 37.5. Mean Length: 3.07
#  Epoch: 7471. Mean Return: 40.0. Mean Length: 2.91
#  Epoch: 7481. Mean Return: 37.5. Mean Length: 3.07
#  Epoch: 7491. Mean Return: 39.3. Mean Length: 2.97
#  Epoch: 7501. Mean Return: 40.5. Mean Length: 2.85
#  Epoch: 7511. Mean Return: 39.3. Mean Length: 2.94
#  Epoch: 7521. Mean Return: 40.7. Mean Length: 2.83
#  Epoch: 7531. Mean Return: 37.7. Mean Length: 3.08
#  Epoch: 7541. Mean Return: 40.1. Mean Length: 2.9
#  Epoch: 7551. Mean Return: 39.8. Mean Length: 2.89
#  Epoch: 7561. Mean Return: 41.4. Mean Length: 2.78
#  Epoch: 7571. Mean Return: 41.7. Mean Length: 2.76
#  Epoch: 7581. Mean Return: 37.9. Mean Length: 3.09
#  Epoch: 7591. Mean Return: 42.0. Mean Length: 2.73
#  Epoch: 7601. Mean Return: 38.4. Mean Length: 3.03
#  Epoch: 7611. Mean Return: 41.4. Mean Length: 2.76
#  Epoch: 7621. Mean Return: 41.5. Mean Length: 2.76
#  Epoch: 7631. Mean Return: 39.6. Mean Length: 2.94
#  Epoch: 7641. Mean Return: 39.0. Mean Length: 2.99
#  Epoch: 7651. Mean Return: 40.4. Mean Length: 2.85
#  Epoch: 7661. Mean Return: 40.8. Mean Length: 2.84
#  Epoch: 7671. Mean Return: 41.2. Mean Length: 2.79
#  Epoch: 7681. Mean Return: 39.1. Mean Length: 2.99
#  Epoch: 7691. Mean Return: 42.1. Mean Length: 2.72
#  Epoch: 7701. Mean Return: 40.6. Mean Length: 2.85
#  Epoch: 7711. Mean Return: 40.1. Mean Length: 2.9
#  Epoch: 7721. Mean Return: 40.4. Mean Length: 2.85
#  Epoch: 7731. Mean Return: 39.2. Mean Length: 2.96
#  Epoch: 7741. Mean Return: 38.0. Mean Length: 3.06
#  Epoch: 7751. Mean Return: 40.8. Mean Length: 2.82
#  Epoch: 7761. Mean Return: 42.3. Mean Length: 2.7
#  Epoch: 7771. Mean Return: 40.0. Mean Length: 2.89
#  Epoch: 7781. Mean Return: 38.6. Mean Length: 3.01
#  Epoch: 7791. Mean Return: 40.6. Mean Length: 2.85
#  Epoch: 7801. Mean Return: 40.5. Mean Length: 2.82
#  Epoch: 7811. Mean Return: 39.9. Mean Length: 2.91
#  Epoch: 7821. Mean Return: 40.4. Mean Length: 2.89
#  Epoch: 7831. Mean Return: 37.3. Mean Length: 3.1
#  Epoch: 7841. Mean Return: 38.9. Mean Length: 2.98
#  Epoch: 7851. Mean Return: 41.5. Mean Length: 2.77
#  Epoch: 7861. Mean Return: 42.0. Mean Length: 2.72
#  Epoch: 7871. Mean Return: 38.8. Mean Length: 3.0
#  Epoch: 7881. Mean Return: 39.3. Mean Length: 2.96
#  Epoch: 7891. Mean Return: 41.8. Mean Length: 2.74
#  Epoch: 7901. Mean Return: 38.6. Mean Length: 3.01
#  Epoch: 7911. Mean Return: 38.9. Mean Length: 2.96
#  Epoch: 7921. Mean Return: 39.0. Mean Length: 2.95
#  Epoch: 7931. Mean Return: 39.1. Mean Length: 2.96
#  Epoch: 7941. Mean Return: 40.2. Mean Length: 2.88
#  Epoch: 7951. Mean Return: 39.1. Mean Length: 2.95
#  Epoch: 7961. Mean Return: 40.7. Mean Length: 2.84
#  Epoch: 7971. Mean Return: 37.2. Mean Length: 3.11
#  Epoch: 7981. Mean Return: 42.0. Mean Length: 2.74
#  Epoch: 7991. Mean Return: 41.1. Mean Length: 2.82
#  Epoch: 8001. Mean Return: 42.0. Mean Length: 2.75
#  Epoch: 8011. Mean Return: 39.6. Mean Length: 2.92
#  Epoch: 8021. Mean Return: 40.1. Mean Length: 2.88
#  Epoch: 8031. Mean Return: 40.1. Mean Length: 2.89
#  Epoch: 8041. Mean Return: 40.8. Mean Length: 2.82
#  Epoch: 8051. Mean Return: 39.9. Mean Length: 2.9
#  Epoch: 8061. Mean Return: 38.7. Mean Length: 3.0
#  Epoch: 8071. Mean Return: 39.0. Mean Length: 2.96
#  Epoch: 8081. Mean Return: 39.5. Mean Length: 2.93
#  Epoch: 8091. Mean Return: 41.0. Mean Length: 2.81
#  Epoch: 8101. Mean Return: 39.6. Mean Length: 2.94
#  Epoch: 8111. Mean Return: 39.2. Mean Length: 2.96
#  Epoch: 8121. Mean Return: 38.3. Mean Length: 3.03
#  Epoch: 8131. Mean Return: 39.0. Mean Length: 2.98
#  Epoch: 8141. Mean Return: 40.7. Mean Length: 2.83
#  Epoch: 8151. Mean Return: 37.7. Mean Length: 3.08
#  Epoch: 8161. Mean Return: 40.9. Mean Length: 2.83
#  Epoch: 8171. Mean Return: 41.4. Mean Length: 2.79
#  Epoch: 8181. Mean Return: 40.7. Mean Length: 2.82
#  Epoch: 8191. Mean Return: 43.3. Mean Length: 2.62
#  Epoch: 8201. Mean Return: 39.7. Mean Length: 2.92
#  Epoch: 8211. Mean Return: 41.2. Mean Length: 2.79
#  Epoch: 8221. Mean Return: 39.2. Mean Length: 2.97
#  Epoch: 8231. Mean Return: 37.3. Mean Length: 3.1
#  Epoch: 8241. Mean Return: 40.0. Mean Length: 2.89
#  Epoch: 8251. Mean Return: 40.5. Mean Length: 2.84
#  Epoch: 8261. Mean Return: 42.0. Mean Length: 2.73
#  Epoch: 8271. Mean Return: 41.5. Mean Length: 2.77
#  Epoch: 8281. Mean Return: 40.1. Mean Length: 2.89
#  Epoch: 8291. Mean Return: 40.2. Mean Length: 2.86
#  Epoch: 8301. Mean Return: 41.8. Mean Length: 2.74
#  Epoch: 8311. Mean Return: 41.2. Mean Length: 2.79
#  Epoch: 8321. Mean Return: 42.6. Mean Length: 2.67
#  Epoch: 8331. Mean Return: 39.7. Mean Length: 2.89
#  Epoch: 8341. Mean Return: 38.5. Mean Length: 2.99
#  Epoch: 8351. Mean Return: 38.1. Mean Length: 3.02
#  Epoch: 8361. Mean Return: 38.4. Mean Length: 3.01
#  Epoch: 8371. Mean Return: 39.1. Mean Length: 2.96
#  Epoch: 8381. Mean Return: 40.7. Mean Length: 2.82
#  Epoch: 8391. Mean Return: 40.7. Mean Length: 2.84
#  Epoch: 8401. Mean Return: 37.6. Mean Length: 3.07
#  Epoch: 8411. Mean Return: 39.0. Mean Length: 2.97
#  Epoch: 8421. Mean Return: 38.6. Mean Length: 3.0
#  Epoch: 8431. Mean Return: 40.1. Mean Length: 2.86
#  Epoch: 8441. Mean Return: 41.7. Mean Length: 2.74
#  Epoch: 8451. Mean Return: 39.7. Mean Length: 2.93
#  Epoch: 8461. Mean Return: 39.5. Mean Length: 2.91
#  Epoch: 8471. Mean Return: 44.3. Mean Length: 2.53
#  Epoch: 8481. Mean Return: 40.9. Mean Length: 2.8
#  Epoch: 8491. Mean Return: 39.6. Mean Length: 2.91
#  Epoch: 8501. Mean Return: 39.5. Mean Length: 2.95
#  Epoch: 8511. Mean Return: 40.3. Mean Length: 2.86
#  Epoch: 8521. Mean Return: 39.7. Mean Length: 2.91
#  Epoch: 8531. Mean Return: 39.1. Mean Length: 2.97
#  Epoch: 8541. Mean Return: 42.5. Mean Length: 2.7
#  Epoch: 8551. Mean Return: 42.1. Mean Length: 2.7
#  Epoch: 8561. Mean Return: 41.1. Mean Length: 2.81
#  Epoch: 8571. Mean Return: 39.5. Mean Length: 2.92
#  Epoch: 8581. Mean Return: 38.8. Mean Length: 2.99
#  Epoch: 8591. Mean Return: 42.0. Mean Length: 2.74
#  Epoch: 8601. Mean Return: 38.9. Mean Length: 2.99
#  Epoch: 8611. Mean Return: 40.8. Mean Length: 2.8
#  Epoch: 8621. Mean Return: 39.2. Mean Length: 2.96
#  Epoch: 8631. Mean Return: 40.1. Mean Length: 2.88
#  Epoch: 8641. Mean Return: 42.9. Mean Length: 2.66
#  Epoch: 8651. Mean Return: 39.7. Mean Length: 2.89
#  Epoch: 8661. Mean Return: 41.9. Mean Length: 2.73
#  Epoch: 8671. Mean Return: 37.5. Mean Length: 3.08
#  Epoch: 8681. Mean Return: 39.5. Mean Length: 2.93
#  Epoch: 8691. Mean Return: 41.0. Mean Length: 2.82
#  Epoch: 8701. Mean Return: 42.2. Mean Length: 2.72
#  Epoch: 8711. Mean Return: 39.9. Mean Length: 2.91
#  Epoch: 8721. Mean Return: 40.3. Mean Length: 2.92
#  Epoch: 8731. Mean Return: 40.7. Mean Length: 2.83
#  Epoch: 8741. Mean Return: 39.7. Mean Length: 2.91
#  Epoch: 8751. Mean Return: 40.1. Mean Length: 2.87
#  Epoch: 8761. Mean Return: 41.7. Mean Length: 2.77
#  Epoch: 8771. Mean Return: 40.9. Mean Length: 2.82
#  Epoch: 8781. Mean Return: 42.8. Mean Length: 2.67
#  Epoch: 8791. Mean Return: 41.0. Mean Length: 2.8
#  Epoch: 8801. Mean Return: 41.9. Mean Length: 2.74
#  Epoch: 8811. Mean Return: 39.7. Mean Length: 2.89
#  Epoch: 8821. Mean Return: 39.7. Mean Length: 2.91
#  Epoch: 8831. Mean Return: 39.7. Mean Length: 2.91
#  Epoch: 8841. Mean Return: 43.0. Mean Length: 2.65
#  Epoch: 8851. Mean Return: 39.1. Mean Length: 2.95
#  Epoch: 8861. Mean Return: 39.4. Mean Length: 2.95
#  Epoch: 8871. Mean Return: 40.3. Mean Length: 2.86
#  Epoch: 8881. Mean Return: 40.7. Mean Length: 2.85
#  Epoch: 8891. Mean Return: 42.3. Mean Length: 2.71
#  Epoch: 8901. Mean Return: 42.2. Mean Length: 2.72
#  Epoch: 8911. Mean Return: 39.3. Mean Length: 2.97
#  Epoch: 8921. Mean Return: 38.1. Mean Length: 3.03
#  Epoch: 8931. Mean Return: 39.0. Mean Length: 2.96
#  Epoch: 8941. Mean Return: 40.9. Mean Length: 2.82
#  Epoch: 8951. Mean Return: 36.6. Mean Length: 3.16
#  Epoch: 8961. Mean Return: 42.2. Mean Length: 2.7
#  Epoch: 8971. Mean Return: 42.0. Mean Length: 2.73
#  Epoch: 8981. Mean Return: 41.0. Mean Length: 2.8
#  Epoch: 8991. Mean Return: 39.0. Mean Length: 2.98
#  Epoch: 9001. Mean Return: 41.3. Mean Length: 2.79
#  Epoch: 9011. Mean Return: 40.4. Mean Length: 2.83
#  Epoch: 9021. Mean Return: 37.3. Mean Length: 3.1
#  Epoch: 9031. Mean Return: 38.5. Mean Length: 3.01
#  Epoch: 9041. Mean Return: 39.8. Mean Length: 2.88
#  Epoch: 9051. Mean Return: 38.2. Mean Length: 3.04
#  Epoch: 9061. Mean Return: 38.4. Mean Length: 3.02
#  Epoch: 9071. Mean Return: 44.2. Mean Length: 2.53
#  Epoch: 9081. Mean Return: 39.2. Mean Length: 2.94
#  Epoch: 9091. Mean Return: 38.9. Mean Length: 2.97
#  Epoch: 9101. Mean Return: 41.3. Mean Length: 2.78
#  Epoch: 9111. Mean Return: 40.0. Mean Length: 2.87
#  Epoch: 9121. Mean Return: 39.4. Mean Length: 2.93
#  Epoch: 9131. Mean Return: 39.3. Mean Length: 2.95
#  Epoch: 9141. Mean Return: 42.1. Mean Length: 2.73
#  Epoch: 9151. Mean Return: 39.3. Mean Length: 2.94
#  Epoch: 9161. Mean Return: 41.0. Mean Length: 2.79
#  Epoch: 9171. Mean Return: 38.9. Mean Length: 2.99
#  Epoch: 9181. Mean Return: 38.2. Mean Length: 3.03
#  Epoch: 9191. Mean Return: 39.6. Mean Length: 2.91
#  Epoch: 9201. Mean Return: 40.8. Mean Length: 2.82
#  Epoch: 9211. Mean Return: 41.2. Mean Length: 2.79
#  Epoch: 9221. Mean Return: 40.6. Mean Length: 2.84
#  Epoch: 9231. Mean Return: 41.4. Mean Length: 2.77
#  Epoch: 9241. Mean Return: 40.9. Mean Length: 2.83
#  Epoch: 9251. Mean Return: 38.0. Mean Length: 3.06
#  Epoch: 9261. Mean Return: 39.7. Mean Length: 2.91
#  Epoch: 9271. Mean Return: 41.0. Mean Length: 2.83
#  Epoch: 9281. Mean Return: 41.1. Mean Length: 2.79
#  Epoch: 9291. Mean Return: 41.8. Mean Length: 2.74
#  Epoch: 9301. Mean Return: 41.0. Mean Length: 2.82
#  Epoch: 9311. Mean Return: 41.0. Mean Length: 2.8
#  Epoch: 9321. Mean Return: 38.9. Mean Length: 2.97
#  Epoch: 9331. Mean Return: 41.7. Mean Length: 2.74
#  Epoch: 9341. Mean Return: 39.6. Mean Length: 2.92
#  Epoch: 9351. Mean Return: 38.5. Mean Length: 3.01
#  Epoch: 9361. Mean Return: 38.0. Mean Length: 3.04
#  Epoch: 9371. Mean Return: 40.9. Mean Length: 2.82
#  Epoch: 9381. Mean Return: 42.7. Mean Length: 2.68
#  Epoch: 9391. Mean Return: 36.2. Mean Length: 3.19
#  Epoch: 9401. Mean Return: 42.4. Mean Length: 2.69
#  Epoch: 9411. Mean Return: 39.8. Mean Length: 2.91
#  Epoch: 9421. Mean Return: 41.6. Mean Length: 2.76
#  Epoch: 9431. Mean Return: 42.9. Mean Length: 2.65
#  Epoch: 9441. Mean Return: 39.6. Mean Length: 2.92
#  Epoch: 9451. Mean Return: 37.8. Mean Length: 3.08
#  Epoch: 9461. Mean Return: 41.5. Mean Length: 2.75
#  Epoch: 9471. Mean Return: 42.0. Mean Length: 2.73
#  Epoch: 9481. Mean Return: 40.8. Mean Length: 2.81
#  Epoch: 9491. Mean Return: 42.6. Mean Length: 2.66
#  Epoch: 9501. Mean Return: 40.4. Mean Length: 2.86
#  Epoch: 9511. Mean Return: 42.7. Mean Length: 2.69
#  Epoch: 9521. Mean Return: 41.7. Mean Length: 2.75
#  Epoch: 9531. Mean Return: 44.3. Mean Length: 2.55
#  Epoch: 9541. Mean Return: 39.0. Mean Length: 2.96
#  Epoch: 9551. Mean Return: 39.7. Mean Length: 2.91
#  Epoch: 9561. Mean Return: 42.9. Mean Length: 2.65
#  Epoch: 9571. Mean Return: 40.5. Mean Length: 2.85
#  Epoch: 9581. Mean Return: 38.5. Mean Length: 3.01
#  Epoch: 9591. Mean Return: 40.8. Mean Length: 2.84
#  Epoch: 9601. Mean Return: 40.4. Mean Length: 2.83
#  Epoch: 9611. Mean Return: 38.5. Mean Length: 3.0
#  Epoch: 9621. Mean Return: 41.2. Mean Length: 2.77
#  Epoch: 9631. Mean Return: 41.3. Mean Length: 2.77
#  Epoch: 9641. Mean Return: 41.0. Mean Length: 2.82
#  Epoch: 9651. Mean Return: 40.8. Mean Length: 2.84
#  Epoch: 9661. Mean Return: 41.4. Mean Length: 2.78
#  Epoch: 9671. Mean Return: 41.1. Mean Length: 2.79
#  Epoch: 9681. Mean Return: 41.0. Mean Length: 2.81
#  Epoch: 9691. Mean Return: 40.1. Mean Length: 2.88
#  Epoch: 9701. Mean Return: 42.4. Mean Length: 2.7
#  Epoch: 9711. Mean Return: 40.4. Mean Length: 2.88
#  Epoch: 9721. Mean Return: 41.1. Mean Length: 2.78
#  Epoch: 9731. Mean Return: 40.1. Mean Length: 2.88
#  Epoch: 9741. Mean Return: 40.0. Mean Length: 2.91
#  Epoch: 9751. Mean Return: 41.6. Mean Length: 2.77
#  Epoch: 9761. Mean Return: 39.7. Mean Length: 2.91
#  Epoch: 9771. Mean Return: 39.7. Mean Length: 2.9
#  Epoch: 9781. Mean Return: 39.3. Mean Length: 2.94
#  Epoch: 9791. Mean Return: 40.9. Mean Length: 2.83
#  Epoch: 9801. Mean Return: 41.1. Mean Length: 2.81
#  Epoch: 9811. Mean Return: 40.4. Mean Length: 2.84
#  Epoch: 9821. Mean Return: 41.4. Mean Length: 2.77
#  Epoch: 9831. Mean Return: 41.0. Mean Length: 2.81
#  Epoch: 9841. Mean Return: 44.7. Mean Length: 2.5
#  Epoch: 9851. Mean Return: 39.3. Mean Length: 2.95
#  Epoch: 9861. Mean Return: 43.0. Mean Length: 2.64
#  Epoch: 9871. Mean Return: 41.9. Mean Length: 2.75
#  Epoch: 9881. Mean Return: 40.1. Mean Length: 2.88
#  Epoch: 9891. Mean Return: 42.6. Mean Length: 2.67
#  Epoch: 9901. Mean Return: 39.4. Mean Length: 2.93
#  Epoch: 9911. Mean Return: 40.3. Mean Length: 2.86
#  Epoch: 9921. Mean Return: 41.0. Mean Length: 2.81
#  Epoch: 9931. Mean Return: 40.8. Mean Length: 2.82
#  Epoch: 9941. Mean Return: 43.7. Mean Length: 2.58
#  Epoch: 9951. Mean Return: 38.2. Mean Length: 3.02
#  Epoch: 9961. Mean Return: 38.8. Mean Length: 3.0
#  Epoch: 9971. Mean Return: 42.1. Mean Length: 2.72
#  Epoch: 9981. Mean Return: 38.8. Mean Length: 2.98
#  Epoch: 9991. Mean Return: 38.4. Mean Length: 3.0
